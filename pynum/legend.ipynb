# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[45,67,33,67,12]
y1=[41,60,13,66,13]
plt.figure(figsize=[5,3])
plt.plot(x,y,label="male")
plt.plot(x,y1,label="female")
plt.savefig("ssaa.png",facecolor="red")##it save figure in file
plt.legend()
plt.show()

# %%
plt.figure(figsize=[5,3])
plt.plot(x,y,label="male")
plt.plot(x,y1,label="female")
plt.legend(bbox_to_anchor=(0.8,1.5))
plt.show()
