# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data={"days":[1,2,3,4,5],
      "nop":[50,40,60,30,44],
      "weather":["sunny","rainy","rainy","sunny","sunny"]}
df=pd.DataFrame(data)
print(df)
sns.lineplot(data,x="days",y="nop")
plt.show()
# Out:
#    days  nop weather
# 0     1   50   sunny
# 1     2   40   rainy
# 2     3   60   rainy
# 3     4   30   sunny
# 4     5   44   sunny

# %%
sns.lineplot(data,x="days",y="nop",hue="weather")
# Out:
# <Axes: xlabel='days', ylabel='nop'>

# %%
color=sns.color_palette("viridis")
sns.lineplot(data,x="days",y="nop",hue="weather",palette=color)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12508\3590277571.py:2: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.lineplot(data,x="days",y="nop",hue="weather",palette=color)
