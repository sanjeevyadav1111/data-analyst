# %%
import matplotlib.pyplot as plt
l=[25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55]
plt.stem(l)
plt.show()

# %%
plt.stem(l,orientation="horizontal")
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stem(l,linefmt="--")
plt.plot(l)
