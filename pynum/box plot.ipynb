# %%
import matplotlib.pyplot as plt
l=[25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55]
plt.boxplot(l)
plt.show()

# %%
l1=[2,5,1,7,9,8,5,7,6,5,7,22,6,55]
plt.boxplot(l,l1)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11360\3818016993.py:2: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(l,l1)

# %%
import pandas as pd

data =pd.read_excel("C:/Users/hp/Downloads/Book1.xlsx")
df=pd.DataFrame(data)
print(df)
plt.boxplot(df["Amount ($)"])
plt.show()
# Out:
#         Date        Description  Amount ($)   Payment Mode Category
# 0 2025-02-01    Office Supplies       150.0    Credit Card  Expense
# 1 2025-02-03     Client Payment      1200.0  Bank Transfer   Income
# 2 2025-02-04      Lunch Meeting        45.5           Cash  Expense
# 3 2025-02-05  Project Milestone      2500.0         PayPal   Income
# 4 2025-02-06   Software License       300.0    Credit Card  Expense
# C:\Users\hp\AppData\Local\Temp\ipykernel_11360\3285298210.py:6: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(df["Amount ($)"],l)
