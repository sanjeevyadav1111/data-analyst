# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from sklearn import preprocessing
df=pd.read_csv(r"C:/Users/hp/Downloads/Churn_Modelling1.csv")

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
le=preprocessing.LabelEncoder()
df['Gender_label']=le.fit_transform(df.Gender.values)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Gender_label
# 0          1               1        101348.88       1             0
# 1          0               1        112542.58       0             0
# 2          1               0        113931.57       1             0
# 3          0               0         93826.63       0             0
# 4          1               1         79084.10       0             0

# %%
df.Gender_label.value_counts()
# Out:
# Gender_label
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %% [markdown]
# LABLE ENCODING METHOD

# %%
lab=preprocessing.LabelEncoder()
df["Geography_label"]=lab.fit_transform(df.Geography.values)
df[['Age', 'Gender', 'Gender_label', 'Geography', 'Geography_label']].head(20)
# Out:
#     Age  Gender  Gender_label Geography  Geography_label
# 0    42  Female             0    France                0
# 1    41  Female             0     Spain                2
# 2    42  Female             0    France                0
# 3    39  Female             0    France                0
# 4    43  Female             0     Spain                2
# 5    44    Male             1     Spain                2
# 6    50    Male             1    France                0
# 7    29  Female             0   Germany                1
# 8    44    Male             1    France                0
# 9    27    Male             1    France                0
# 10   31    Male             1    France                0
# 11   24    Male             1     Spain                2
# 12   34  Female             0    France                0
# 13   25  Female             0    France                0
# 14   35  Female             0     Spain                2
# ...

# %%
    # One hot encoding for categorical variables
one_hot = pd.get_dummies(df['Geography'])
one_hot.head()
# Out:
#    France  Germany  Spain
# 0    True    False  False
# 1   False    False   True
# 2    True    False  False
# 3    True    False  False
# 4   False    False   True

# %%
#  Encoding all values in the dataframe
# This will convert all categorical variables into dummy/indicator variables
df_dummy = pd.get_dummies(df)
df_dummy.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_label  Geography_label  \
# 0               1        101348.88       1             0                0
# 1               1        112542.58       0             0                2
# 2               0        113931.57       1             0                0
# 3               0         93826.63       0             0                0
# 4               1         79084.10       0             0                2
#
#    Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# ...

# %%
# dummy encofing for categorical variables
# in this case we will drop the first column of each categorical variable
# to avoid the dummy variable trap (multicollinearity)

df_dummy = pd.get_dummies(df,drop_first=True)
df_dummy.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_label  Geography_label  \
# 0               1        101348.88       1             0                0
# 1               1        112542.58       0             0                2
# 2               0        113931.57       1             0                0
# 3               0         93826.63       0             0                0
# 4               1         79084.10       0             0                2
#
#    Geography_Germany  Geography_Spain  Gender_Male
# 0              False            False        False
# ...
