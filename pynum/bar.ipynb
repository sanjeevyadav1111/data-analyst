# %%
import matplotlib.pyplot as plt
y=[98,67,88,95,88]
x=["part1","part2","part3","part4","part5"]
colors=["red","green","blue","yellow"]
plt.bar(x,y,color=colors)
plt.xlabel("parts of harry potter",fontsize=20)
plt.ylabel("popularity",fontsize=20)
plt.title("popularity of different parts of harry potter")
plt.show()

# %%
plt.bar(x,y,color=colors,edgecolor="black")
# Out:
# <BarContainer object of 5 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data =pd.read_excel("C:/Users/hp/Downloads/FSI-2023-DOWNLOAD.xlsx")
df=pd.DataFrame(data)
print(df)
plt.bar(df["Year"],df["S1: Demographic Pressures "])
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %%
df.columns = df.columns.str.strip()
se=data.head(4)
se=data.tail(4)

# %%
plt.bar(se["Country"],se["S1: Demographic Pressures"])
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd
import numpy as np
dat =pd.read_excel("C:/Users/hp/Downloads/paint payment history.xlsx")
print(data)
print(data["Suresh"].sum(),"out of ",500*7)
# Out:
#         Date  Suresh payment mode  Ramesh Payment mode
# 0 2025-04-02     500         Cash     NaN          NaN
# 1 2025-05-02     100         Cash     NaN          NaN
# 2 2025-06-02     400         Cash     NaN          NaN
# 3 2025-07-02     500         Cash   500.0         Cash
# 1500 out of  3500
